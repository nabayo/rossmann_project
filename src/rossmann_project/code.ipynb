# %%
import boto3

# %% [markdown]
# ## Data loading in AWS

# %%
s3 = boto3.client('s3')
s3.upload_file('data/train.csv', 'nabilath-rossmann-project', 'raw/train.csv')
s3.upload_file('data/store.csv', 'nabilath-rossmann-project', 'raw/store.csv')
